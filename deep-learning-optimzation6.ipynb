# %% [markdown]
# # Model Optimization 6

# %% [markdown]
# I have
# * changed act. func to TANH
# * 4 layers
# * less neurons
# * back to 100 epochs

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head(1)
# Out:
#         EIN                          NAME APPLICATION_TYPE  AFFILIATION  \
# 0  10520599  BLUE KNIGHTS MOTORCYCLE CLUB              T10  Independent
#
#   CLASSIFICATION    USE_CASE ORGANIZATION  STATUS INCOME_AMT  \
# 0          C1000  ProductDev  Association       1          0
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0                      N     5000              1

# %%
#looking for nulls
application_df.isnull().sum()
# Out:
# EIN                       0
# NAME                      0
# APPLICATION_TYPE          0
# AFFILIATION               0
# CLASSIFICATION            0
# USE_CASE                  0
# ORGANIZATION              0
# STATUS                    0
# INCOME_AMT                0
# SPECIAL_CONSIDERATIONS    0
# ASK_AMT                   0
# IS_SUCCESSFUL             0
# dtype: int64

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
## I drop ' ASK_AMT ' as well, too many different values

application_df.drop(columns=["EIN","NAME"], inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df["APPLICATION_TYPE"].value_counts()
app_type_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_count.loc[app_type_count<500].index)
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classif_count = application_df["CLASSIFICATION"].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
(classif_count > 1).sum()
# Out:
# 45

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classif_count.loc[classif_count<500].index)

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_to_numeric = pd.get_dummies(application_df)
app_to_numeric.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
app_to_numeric.describe()
# Out:
#              STATUS       ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# count  34299.000000  3.429900e+04   34299.000000            34299.000000
# mean       0.999854  2.769199e+06       0.532406                0.008047
# std        0.012073  8.713045e+07       0.498956                0.089344
# min        0.000000  5.000000e+03       0.000000                0.000000
# 25%        1.000000  5.000000e+03       0.000000                0.000000
# 50%        1.000000  5.000000e+03       1.000000                0.000000
# 75%        1.000000  7.742000e+03       1.000000                0.000000
# max        1.000000  8.597806e+09       1.000000                1.000000
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# count          34299.000000          34299.000000         34299.000000
# mean               0.015394              0.031050             0.788274
# std                0.123116              0.173457             0.408538
# ...

# %%
app_to_numeric["IS_SUCCESSFUL"].value_counts()
# Out:
# 1    18261
# 0    16038
# Name: IS_SUCCESSFUL, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
X = app_to_numeric.drop(columns="IS_SUCCESSFUL").values
y = app_to_numeric["IS_SUCCESSFUL"].values

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=31,stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# shape
X_test_scaled.shape
# Out:
# (8575, 44)

# %%
X_train_scaled.shape
# Out:
# (25724, 44)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input4 = X_train_scaled.shape[1]
node1 = 120
node2 = 80
node3 = 80
node4 = 20

# %%
nn7 = tf.keras.models.Sequential()

# First hidden layer
nn7.add(tf.keras.layers.Dense(units=node1, activation='tanh', input_dim=input4))

# Second hidden layer
nn7.add(tf.keras.layers.Dense(units=node2, activation='tanh'))

# Third hidden layer
nn7.add(tf.keras.layers.Dense(units=node3, activation='tanh'))

# 4° hidden layer
nn7.add(tf.keras.layers.Dense(units=node4, activation='tanh'))

# Output layer
nn7.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn7.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 120)               5400
#
#  dense_2 (Dense)             (None, 80)                9680
#
#  dense_3 (Dense)             (None, 80)                6480
#
#  dense_4 (Dense)             (None, 20)                1620
#
#  dense_5 (Dense)             (None, 1)                 21
#
# ...
# Total params: 23,201
# Trainable params: 23,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn7.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model_7 = nn7.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 5ms/step - loss: 0.5671 - accuracy: 0.7214
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5542 - accuracy: 0.7298
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5511 - accuracy: 0.7302
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5491 - accuracy: 0.7348
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5476 - accuracy: 0.7319
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5462 - accuracy: 0.7334
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5455 - accuracy: 0.7334
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5446 - accuracy: 0.7347
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5438 - accuracy: 0.7332
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn7.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5613 - accuracy: 0.7264 - 1s/epoch - 4ms/step
# Loss: 0.5612878203392029, Accuracy: 0.7264139652252197

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model_7.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# %%
# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Export our model to HDF5 file
nn7.save("Exports/Result_Model7.h5")

# %% [markdown]
# ### Result for model 7:
# #### Loss: 0.56, Accuracy: 0.73
# #### Very similar result than model 1, 2, 3, 4, 5 and 6
